# %% [markdown]
# # Ejemplo de Notebook en Jupyter
#
# Este es un notebook de ejemplo con Python.
#
# Incluye:
# - Variables
# - Funciones
# - Consulta simple tipo análisis

# %%
# Variables básicas
a = 10
b = 20
suma = a + b
suma
# Out:
# 30

# %%
# Función simple
def calcular_promedio(lista):
    return sum(lista) / len(lista)

datos = [10, 20, 30, 40]
calcular_promedio(datos)
# Out:
# 25.0

# %%
# Ejemplo tipo análisis (simulando datos)
import pandas as pd

df = pd.DataFrame({
    'nombre': ['A', 'B', 'C'],
    'ventas': [100, 200, 150]
})

df
# Out:
#   nombre  ventas
# 0      A     100
# 1      B     200
# 2      C     150
