# %%
##asi se hace en linux
# !kaggle datasets download -d shivamb/netflix-shows
#!python -m kaggle datasets download -d shivamb/netflix-shows

#!unzip netflix-shows.zip #es como un comando de consola es en linux

import zipfile

with zipfile.ZipFile("netflix-shows.zip", 'r') as zip_ref:
    zip_ref.extractall()

import pandas as pd

df_netflix = pd.read_csv(  #se guarda en esta variable el csv
    'netflix_titles.csv',
    na_values=['', 'NaN', 'Not Given'] #estos valores se ignoran 
    )

df_netflix.head()
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shivamb/netflix-shows
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# 100%|██████████| 1.34M/1.34M [00:00<00:00, 465MB/s]
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
# ...
